# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\rohit\OneDrive\Downloads\covid19_Confirmed_dataset.csv")

# %%
df
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# ...

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
df.tail()
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# 261        0        0        0        0        0  ...        6        6
# 262        0        0        0        0        0  ...        4        4
# 263        0        0        0        0        0  ...        1        1
# 264        0        0        0        0        0  ...        0        0
# 265        0        0        0        0        0  ...        0        0
#
#      4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
groupeddata = df.groupby("Country/Region")

# %%
groupeddata

# %%
groupeddataaggregation = df.groupby("Country/Region").sum()

# %%
groupeddataaggregation
# Out:
#                    Province/State        Lat       Long  1/22/20  1/23/20  \
# Country/Region
# Afghanistan                     0  33.000000  65.000000        0        0
# Albania                         0  41.153300  20.168300        0        0
# Algeria                         0  28.033900   1.659600        0        0
# Andorra                         0  42.506300   1.521800        0        0
# Angola                          0 -11.202700  17.873900        0        0
# ...                           ...        ...        ...      ...      ...
# West Bank and Gaza              0  31.952200  35.233200        0        0
# Western Sahara                  0  24.215500 -12.885800        0        0
# Yemen                           0  15.552727  48.516388        0        0
# Zambia                          0 -15.416700  28.283300        0        0
# Zimbabwe                        0 -20.000000  30.000000        0        0
#
# ...

# %%
groupeddataaggregation.size
# Out:
# 19261

# %%
groupeddataaggregation.shape
# Out:
# (187, 103)

# %%
groupeddataaggregation.ndim
# Out:
# 2

# %%
groupeddataaggregation.head()
# Out:
#                Province/State      Lat     Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan                 0  33.0000  65.0000        0        0        0
# Albania                     0  41.1533  20.1683        0        0        0
# Algeria                     0  28.0339   1.6596        0        0        0
# Andorra                     0  42.5063   1.5218        0        0        0
# Angola                      0 -11.2027  17.8739        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  4/21/20  4/22/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...     1092     1176
# Albania               0        0        0        0  ...      609      634
# Algeria               0        0        0        0  ...     2811     2910
# Andorra               0        0        0        0  ...      717      723
# ...

# %%
groupeddataaggregation.tail()
# Out:
#                    Province/State        Lat       Long  1/22/20  1/23/20  \
# Country/Region
# West Bank and Gaza              0  31.952200  35.233200        0        0
# Western Sahara                  0  24.215500 -12.885800        0        0
# Yemen                           0  15.552727  48.516388        0        0
# Zambia                          0 -15.416700  28.283300        0        0
# Zimbabwe                        0 -20.000000  30.000000        0        0
#
#                     1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  ...  4/21/20  \
# Country/Region                                                   ...
# West Bank and Gaza        0        0        0        0        0  ...      466
# Western Sahara            0        0        0        0        0  ...        6
# Yemen                     0        0        0        0        0  ...        1
# Zambia                    0        0        0        0        0  ...       70
# ...

# %%
groupeddataaggregation.loc["Afghanistan"].plot()
# Out:
# <Axes: >

# %%
groupeddataaggregation.loc["Afghanistan"].plot()
# Out:
# <Axes: >

# %%
groupeddataaggregation.loc["Nigeria"].plot()
# Out:
# <Axes: >

# %%
groupeddataaggregation.loc["Afghanistan"][:3].plot()
# Out:
# <Axes: >

# %%
groupeddataaggregation.loc["Afghanistan"].diff().plot()
# Out:
# <Axes: >

# %%
groupeddataaggregation.loc["Nigeria"].diff().plot()
# Out:
# <Axes: >

# %%
df1 = groupeddataaggregation
