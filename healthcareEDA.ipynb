# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\Naresh it\Data science and AI Full stack\Python\heart dataset\heart.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.size
# Out:
# 4242

# %%
df.shape
# Out:
# (303, 14)

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df['sex'].nunique()
# Out:
# 2

# %%
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
sns.countplot(data = df, x = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
sns.countplot(data = df, x = 'sex', hue = 'target')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['cp'].nunique()

#so as per the below result, there are 4 types of chest pain these patients have
# Out:
# 4

# %%
df['sex'].nunique()
# Out:
# 2

# %%
#there are 2 types of genders

# %%
plt.subplots(figsize = (8,4))
sns.violinplot(data = df, x = 'sex', y = 'chol',color = 'orange')
# Out:
# <Axes: xlabel='sex', ylabel='chol'>

# %%
sns.countplot(hue = 'sex', x = 'target', data = df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
correlation = df.corr()

# %%
correlation['target'].sort_values(ascending = False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
sns.countplot(y = 'target', hue = 'sex', data = df,palette = 'Set3')
# Out:
# <Axes: xlabel='count', ylabel='target'>

# %%
sns.countplot(data = df, hue = 'sex', y = 'thalach', palette = 'Set2')
# Out:
# <Axes: xlabel='count', ylabel='thalach'>

# %%
ax = sns.countplot(x="target", data=df, facecolor=(0, 0, 0, 0), linewidth=5, edgecolor=sns.color_palette("dark", 3))

# %%
df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
#1 is presence of heart disease, 0 is absence of heart disease

# %%
sns.countplot(x = 'cp', hue = 'target' , data = df)
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
x = df['thalach']

# %%
x
# Out:
# 0      150
# 1      187
# 2      172
# 3      178
# 4      163
#       ...
# 298    123
# 299    132
# 300    141
# 301    115
# 302    174
# Name: thalach, Length: 303, dtype: int64

# %%
sns.distplot(x, bins = 12)
plt.grid(True)
#THIS IS THE FREQUENCY DISTRIBUTION OF THALACH TABLE

# %%
sns.distplot(x,bins = 10, vertical = True)
plt.grid(True)

# %%
plt.subplots(figsize = (8,4))
sns.stripplot(x = 'target', y = 'thalach', data = df, palette = "Set1")
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
##### Interpretation We can see that those people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).

# %%
sns.boxplot(x = "sex" , y = "thalach", hue = "target",data = df)

#as you can observe below men who have heart disease have higher heart rate than women who have heart disease
# Out:
# <Axes: xlabel='sex', ylabel='thalach'>

# %%
plt.figure(figsize=(16,12))
plt.title('Co-relation heatmap of heart disease dataset')
sns.heatmap(correlation,square = True, annot = True, fmt ='.2f',linecolor = 'white')
# Out:
# <Axes: title={'center': 'Co-relation heatmap of heart disease dataset'}>

# %%
sns.regplot(x = "age", y = "trestbps", data = df)
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
sns.scatterplot(x = 'age', y = 'chol', data = df)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.boxplot(x = "sex", y = "chol", hue = "target", data = df)
# Out:
# <Axes: xlabel='sex', ylabel='chol'>

# %%
sns.regplot(x = "chol", y = "thalach", data = df)
# Out:
# <Axes: xlabel='chol', ylabel='thalach'>

# %%
#now let's check if there are any null values in the data

df.isna().sum()

#see the below result, it means there are no null values in our data
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df['chol'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 303 entries, 0 to 302
# Series name: chol
# Non-Null Count  Dtype
# --------------  -----
# 303 non-null    int64
# dtypes: int64(1)
# memory usage: 2.5 KB

# %%
df['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
sns.boxplot(x = 'age', y = 'chol', data = df)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.boxplot(x = df['age'])

#age has no outliers
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(x = df['chol'])

#cholestrol has outliers
# Out:
# <Axes: xlabel='chol'>

# %%
sns.boxplot(x = df['oldpeak'])

#again oldpeak has outliers
# Out:
# <Axes: xlabel='oldpeak'>

# %%
sns.boxplot(x = df['thalach'])

#thalach has an outlier
# Out:
# <Axes: xlabel='thalach'>
